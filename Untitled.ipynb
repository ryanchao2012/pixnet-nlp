# %%
# %matplotlib inline
import codecs, re, jieba
import gensim
import difflib
import numpy as np
import random
from smart_open import smart_open
import matplotlib.pyplot as plt
jieba.add_word('龐傍燮謝', freq=10, tag='xx')
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/4_/b_9vfbwx41g4t48jrzr0r4vm0000gn/T/jieba.cache
# Loading model cost 1.298 seconds.
# Prefix dict has been built succesfully.

# %%
model = gensim.models.Word2Vec.load_word2vec_format('w2v-experiment/model/syn0.bin', binary = True)
vocab_size, vector_size = model.syn0.shape
syn1neg = np.zeros((vocab_size, vector_size), dtype=np.float32)
binary_len = np.dtype(np.float32).itemsize * vector_size
with smart_open('w2v-experiment/model/syn1neg.bin') as fin:
    for i in range(vocab_size):
        weights = np.fromstring(fin.read(binary_len), dtype=np.float32)
#         if weights.sum() != 0:
#             syn1neg[i] = weights / ((weights * weights).sum() ** 0.5)
#         else:
        syn1neg[i] = weights

# %%
# model.index2word[-1] # '月季花'
model.syn0[1]
# model['月季花']
# Out:
# array([-0.05783859,  0.03348379,  0.15104674, -0.00795828, -0.00432346,
#        -0.02305857, -0.1941321 ,  0.01818136, -0.14585723,  0.0449975 ,
#         0.11466971,  0.03201884, -0.03041247, -0.07192305,  0.00587473,
#         0.06839263, -0.00521598, -0.0602061 ,  0.16990589, -0.1053398 ,
#        -0.07617206, -0.03960307,  0.03682428, -0.04297646, -0.17641535,
#         0.23105858, -0.09490027,  0.02265082,  0.07011159, -0.23730826,
#        -0.01806434, -0.26921868, -0.11200881, -0.01193818,  0.13664293,
#         0.07615297,  0.06955415, -0.06710563,  0.01586401,  0.14574283,
#        -0.09316104,  0.09887696, -0.26164317, -0.10952692,  0.0830896 ,
#        -0.14705931,  0.03814167, -0.12113235, -0.03128063,  0.05377599,
#         0.03109613,  0.11087636,  0.06083726,  0.14496022, -0.1779516 ,
#         0.10283189,  0.07942818,  0.05897621,  0.07339048, -0.11113805,
#         0.01551922,  0.25446549, -0.04256972, -0.07398622,  0.04314755,
#         0.14691211, -0.00851079,  0.24412356, -0.09468031,  0.11312793,
#         0.01947653,  0.07357328,  0.09466312, -0.26172829, -0.07707694,
#         0.08356623,  0.00831681,  0.13689417, -0.20500515, -0.10526493,
#         0.18643464,  0.04568931, -0.03770652,  0.05835917, -0.08335228,
#         0.18278147,  0.25600266, -0.17254379, -0.04651724, -0.01435732,
#         0.18713313,  0.14466999, -0.07521512,  0.11915602,  0.11552885,
#         0.00740613, -0.2468982 , -0.08871315,  0.10935222, -0.11602537], dtype=float32)

# %%
i = random.choice(range(vocab_size))
# i = 10
print(model.index2word[i])
w = model.syn0[i]
t = np.dot(syn1neg[i], w)
print(t)
print('\n')
# print(np.dot(syn1neg[i], model['她']))
for j in range(10):
    k = random.choice(range(vocab_size))
    if k != i:
        f1 = np.dot(syn1neg[i], model.syn0[k])
        f2 = np.dot(syn1neg[k], w)
        print("{}:\t{:.3f}, {:.3f}, {}, {}".format(model.index2word[k], f1, f2, t > f1, t > f2))
# Out:
# 自作
# -1.28729
#
#
# 熱:	-1.624, -1.012, True, False
# 瑪儂:	-0.648, -1.302, False, True
# 銷量:	-0.926, -0.983, False, False
# 中央區:	-2.532, -2.182, True, True
# トントン:	-0.224, -0.998, False, False
# 忙忙碌碌:	-1.125, -1.388, False, True
# 小妞:	-1.656, -0.854, True, False
# 新武:	-0.768, -1.377, False, True
# 公幹:	-0.754, -1.410, False, True
# 地上:	-1.584, -1.138, True, False

# %%
# a = np.zeros(vocab_size)
# b = np.zeros(vocab_size)
# for i in range(vocab_size):
#     a[i] = np.dot(syn1neg[i], model.syn0[i])
#     l = 0
#     f = 0
#     for j in range(100):
#         k = random.choice(range(vocab_size))
#         if k != i:
#             f = f + np.dot(syn1neg[i], model.syn0[k])
#             l = l + 1
#     b[i] = f / l
# plt.figure(figsize=(24,12))
# plt.grid()
# plt.plot(a)
# plt.plot(b, 'r')

# %%
def simple_preprocess(sample):
    no, content, a, b, c, d, e = re.findall(r'\[(\d+)\](.*)### a:(.*), b:(.*), c:(.*), d:(.*), e:(.*)\[END\]', sample)[0]
    options = [a.strip(), b.strip(), c.strip(), d.strip(), e.strip()]
    content = re.sub('(")(.?)', r'\2', content.strip())
    print(content)
    content = content.strip().replace('︽⊙＿⊙︽', '龐傍燮謝')
    wlist = list(jieba.cut(content))
    qidx = []
    i = 0
    for w in wlist:
        if w == '龐傍燮謝':
            wlist[i] = '*'
            qidx.append(i)
        i += 1
    return (no, wlist, qidx, options)

path = '../gensim/2016-pixnet-ai/pixbot/question_samples/'
# filename = '2016-07-31-15-02-02.txt'
# no = 4
filename = '2016-07-31-20-12-45.txt'
no = 5
def get_sample(file_name, no_sample):
    with codecs.open(file_name, 'r', 'utf-8') as f:
        for line in f:
            for (no, content, a, b, c, d, e) in re.findall(r'\[(\d+)\](.*)### a:(.*), b:(.*), c:(.*), d:(.*), e:(.*)\[END\]', line):
                if int(no) == int(no_sample):
                    return line

no, wlist, qidx, anslist = simple_preprocess(get_sample(path + filename, no))
print(no)
print(wlist)
print(qidx)
print(anslist)
# Out:
# 給大家看看, 我已經全臉都上了保溼水︽⊙＿⊙︽, 我的底妝依然非常的有光澤度!!!!!!!!!!!!!!!!!!
# 5
# ['給', '大家', '看看', ',', ' ', '我', '已經', '全臉', '都', '上', '了', '保溼', '水', '*', ',', ' ', '我', '的', '底妝', '依然', '非常', '的', '有', '光澤度', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!']
# [13]
# ['粉餅', 'hermes', '線條', '黏貼', 'nivea']

# %%
a = wlist[:]
for i in qidx[::-1]:
    del a[i]
print(a)

def normalize_vec(vec):
    mag = ((vec * vec).sum()) ** 0.5
    return vec / mag

arr = np.zeros(vector_size)
for w in a:
    if w in model:
        arr += model[w]
        
for w in anslist:
    if w in model:
        idx = model.vocab[w].index
        print(w, np.dot(normalize_vec(arr), normalize_vec(model[w])), np.dot(arr, syn1neg[idx]), np.dot(model.syn0[idx], syn1neg[idx]))
        print(np.dot(arr, model[w]))
# Out:
# ['給', '大家', '看看', ',', ' ', '我', '已經', '全臉', '都', '上', '了', '保溼', '水', ',', ' ', '我', '的', '底妝', '依然', '非常', '的', '有', '光澤度', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!']
# 粉餅 0.266947236174 -30.7197819265 2.87835
# 39.8335493903
# 線條 0.217636771683 -39.1909982198 3.93342
# 25.4561658421
# 黏貼 0.211986786524 -55.1422230429 2.11204
# 19.7369476458

# %%
w = '賴清德'
idx = model.vocab[w].index
print(w, np.dot(normalize_vec(arr), normalize_vec(model[w])), np.dot(arr, syn1neg[idx]), np.dot(model.syn0[idx], syn1neg[idx]))
print(np.dot(arr, model[w]))
# Out:
# 賴清德 0.629983324325 -10.9365568257 2.09472
# 25.826083566

# %%
word = ' '.join(model.index2word)
# Out:
# 9554

# %%
word.find('唇膏')
# Out:
# 3175

# %%
i = 3175
print(word[i - 1: i + 10])
# 180376 + 30485
# Out:
#  唇膏 如此 國際 立
